# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
print("terminal -> komendy: git status, git pull, git add . (zapis wszystkich plikow), git commin -m "", git push origin main")
# Out:
# terminal -> komendy: git status, git pull, git add . (zapis wszystkich plikow), git commin -m , git push origin main
