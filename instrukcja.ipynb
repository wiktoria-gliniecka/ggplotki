# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.9 kB 262.6 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/60.9 kB 372.4 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 405.6 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB 991.0 kB/s eta 0:00:12
#    ---------------------------------------- 0.1/11.0 MB 871.5 kB/s eta 0:00:13
#     --------------------------------------- 0.1/11.0 MB 944.1 kB/s eta 0:00:12
#     --------------------------------------- 0.2/11.0 MB 1.2 MB/s eta 0:00:09
#    - -------------------------------------- 0.3/11.0 MB 1.4 MB/s eta 0:00:08
# ...

# %%
import pandas as pd

# %%
print("najpierw zapisujemy, potem stage changes, commit, push")
# Out:
# najpierw zapisujemy, potem stage changes, commit, push
